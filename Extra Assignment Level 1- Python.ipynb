# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
Institute_name = input("Enter your Institute name: ")
# Out:
# Enter your Institute name:  Hope AI Institute

# %%
Student_name = input("Enter your name: ")
Age = int(input("Enter your age:"))
School_name=input("Enter your School name")
Degree=input("Enter your degree")
# Out:
# Enter your name:  Gayatri Bala
# Enter your age: 32
# Enter your School name VKV
# Enter your degree B.Tech I.T

# %% [markdown]
# #Addition

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Add = Num1+Num2
print(Add)
# Out:
# Enter Num1 = 55
# Enter Num2 = 12
# 67

# %%
#Subtraction

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Sub = Num1-Num2
print("Sub=",Sub)
# Out:
# Enter Num1 = 34
# Enter Num2 = 11
# Sub= 23

# %%
#Multiplication

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Mul = Num1*Num2
print("Mul=",Mul)
# Out:
# Enter Num1 = 11
# Enter Num2 = 10
# Mul= 110

# %%
#Division

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Div = Num1/Num2
print("Div=",Div)
# Out:
# Enter Num1 = 44
# Enter Num2 = 22
# Div= 2.0

# %%
#Floor Division

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Floor_Div = Num1//Num2
print("Floor Div=",Floor_Div)
# Out:
# Enter Num1 = 66
# Enter Num2 = 23
# Floor Div= 2

# %%
#Modulo

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Mod = Num1%Num2
print("Mod=",Mod)
# Out:
# Enter Num1 = 66
# Enter Num2 = 23
# Mod= 20

# %%
#Power

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Power = Num1^Num2
print("Power=",Power)
# Out:
# Enter Num1 = 3
# Enter Num2 = 3
# Power= 0

# %%
Num1 = int(input("Enter Num1 ="))
Num2 = int(input("Enter Num2 ="))
Power = Num1**Num2
print("Power=",Power)
# Out:
# Enter Num1 = 3
# Enter Num2 = 3
# Power= 27
