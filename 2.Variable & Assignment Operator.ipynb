# %%
num1 = 90
num2 = 40
add = num1 + num2

# %%
num1 = 90
num2 = 40
add = num1 + num2
print ("add")
# Out:
# add

# %%
num1 = 90
num2 = 40
add = num1 + num2
print ("add")
print(add)
# Out:
# add
# 130

# %%
Num1=10 // Create a meaningful variable name for future reference and understanding//
Num2=20
Add=Num1+Num2
Sub=Num1-Num2
print(Add)
print(Sub)
# Out:
# 30
# -10

# %%
Num1=10// Create a meaningful variable name for future reference and understanding)//
Num2=20
Add=Num1+Num2
Sub=Num1-Num2
print(Add)
print(Sub)
# Out:
#   Cell In[6], line 1
#     Num1=10// Create a meaningful variable name for future reference and understanding)//
#                                                                                       ^
# SyntaxError: unmatched ')'

# %%
Num1=10 // Create a meaningful variable name for future reference and understanding//
Num2=20
Add=Num1+Num2
Sub=Num1-Num2
print(Add)
print(Sub)
# Out:
#   Cell In[7], line 1
#     Num1=10 // Create a meaningful variable name for future reference and understanding//
#                       ^
# SyntaxError: invalid syntax

# %%
FirstName = "Gayatri"
firstName = "Bala"
First_name = "Yuvathi"

# %%
print("Addition of 2 numbers is:")
# Out:
# Addition of 2 numbers is:

# %%
First_number = 10
print("First number is :",First_number)
Second_number = 45
# Out:
# First number is : 10

# %%
print("Second number is :",Second_number)
# Out:
# Second number is : 45

# %%
print("Addition of 2 numbers ")
First_number = 10
print("First number is :",First_number)
Second_number = 45
print("Second number is :",Second_number)
print("Addition of 2 numbers is", FirstnNumber+Second_number)
# Out:
# Addition of 2 numbers
# First number is : 10
# Second number is : 45
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       4 Second_number = 45
#       5 print("Second number is :",Second_number)
# ----> 6 print("Addition of 2 numbers is", FirstnNumber+Second_number)
#
# NameError: name 'FirstnNumber' is not defined

# %%
print("Addition of 2 numbers ")
First_number = 10
print("First number is :",First_number)
Second_number = 45
print("Second number is :",Second_number)
print("Addition of 2 numbers is", First_number+Second_number)
# Out:
# Addition of 2 numbers
# First number is : 10
# Second number is : 45
# Addition of 2 numbers is 55
