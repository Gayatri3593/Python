# %%
#1.Find the error in the following Python code:
#import math
#print(Math.sqrt(16))
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
#def my_function():
    #x += 5
    #print(x)

#x = 10
#my_function()

def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
#if x = 10:
    #print("x is 10")
x = 5
if x == 10:
    print("x is 10")

# %%
#4.
#numbers = [5, 3, 8, 2]
#print(numbers.sort())
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
#def square(n):
   # n * n

#print(square(4))
def square(n):
    return n * n

print(square(4))
# Out:
# 16

# %%
#6.
#my_tuple = (1, 2, 3)
#my_tuple[1] = 5

Tuples are immutable and cannot be modified.
Fixed Code:

my_tuple = (1, 5, 3)  # Create a new tuple

# %%
#7.
name = "Alice"
age = 25
#print("My name is %s and I am %d years old" % (name))
print("My name is %s and I am %d years old" % (name, age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
#if a is b:
    #print("Lists are equal")
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
#for i in range(5, 1):
   #print(i)
#The range(5, 1) does not produce any numbers because the default step is +1.
#Fixed Code:


for i in range(5, 1, -1):  # Step should be negative to decrement
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
#print(student[name])
#Issue: The key should be a string, but name is not defined as a variable.
#Fixed Code:

print(student["name"])
# Out:
# John
